# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
import scipy

# %%
df = pd.read_csv("/root/Downloads/framingham.csv")

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
df['cigsPerDay'].fillna(0,inplace = True)

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df['totChol'].fillna(0,inplace = True)

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df['BMI'].fillna(0, inplace = True)

# %%
df['BPMeds'].fillna(0,inplace = True)

# %%
df['heartRate'].fillna(0,inplace = True)

# %%
df['education'].fillna((df['education'].mean()),inplace = True)

# %%
import statistics

# %%
df['glucose'].fillna((statistics.mode(df['glucose'])),inplace = True)

# %%
df.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
fig, axs = plt.subplots(16,1, dpi = 90, figsize= (10,30))
i=0
for col in df.columns:
    axs[i].boxplot(df[col], vert = False)
    axs[i].set_ylabel(col)
    i+=1
plt.show()

# %%
corr= df.corr()

# %%
df.iloc[: , :10]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol
# 0                   0             0         0    195.0
# 1                   0             0         0    250.0
# ...

# %%
plt.figure(dpi=150, figsize=(15,15))
sns.heatmap(df[:10].corr(), annot = True , fmt = '.2f')
plt.show()

# %%
x= df.drop (columns = ['TenYearCHD'])

# %%
y= df['TenYearCHD']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler (feature_range =(0,1))
rescaledX = scaler.fit_transform(x)
rescaledX [:5]
# Out:
# array([[1.        , 0.18421053, 1.        , 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.28017241,
#         0.10638298, 0.23280423, 0.47482394, 0.55944056, 0.10451977],
#        [0.        , 0.36842105, 0.33333333, 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.3591954 ,
#         0.17730496, 0.34920635, 0.50580986, 0.66433566, 0.10169492],
#        [1.        , 0.42105263, 0.        , 1.        , 0.28571429,
#         0.        , 0.        , 0.        , 0.        , 0.35201149,
#         0.20803783, 0.33862434, 0.44612676, 0.52447552, 0.08474576],
#        [0.        , 0.76315789, 0.66666667, 1.        , 0.42857143,
#         0.        , 0.        , 1.        , 0.        , 0.32327586,
#         0.3144208 , 0.4973545 , 0.50316901, 0.45454545, 0.1779661 ],
#        [0.        , 0.36842105, 0.66666667, 1.        , 0.32857143,
#         0.        , 0.        , 0.        , 0.        , 0.40948276,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y ,
                                   random_state=1000, 
                                   test_size=0.10, 
                                   shuffle=True)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf =  LogisticRegression(random_state = 0)

# %%
y_train
# Out:
# 525     0
# 2826    0
# 3000    0
# 4020    0
# 3424    0
#        ..
# 769     0
# 1372    0
# 2398    0
# 3776    0
# 1459    0
# Name: TenYearCHD, Length: 3816, dtype: int64

# %%
clf.fit(x_train,y_train)
# Out:
# /home/crl/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
score = accuracy_score(y_test,y_pred)

# %%
score
# Out:
# 0.8632075471698113

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_test, y_pred, average='macro')
# Out:
# 0.5363499245852187

# %%
df1 = df.drop (columns = ['cigsPerDay'])

# %%
X= df1.drop (columns = ['TenYearCHD'])

# %%
Y= df1['TenYearCHD']

# %%
Scaler1 = MinMaxScaler(feature_range=(0,1))

# %%
rescaledx = Scaler1.fit_transform(X)

# %%
rescaledx[:5]
# Out:
# array([[1.        , 0.18421053, 1.        , 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.28017241, 0.10638298,
#         0.23280423, 0.47482394, 0.55944056, 0.10451977],
#        [0.        , 0.36842105, 0.33333333, 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.3591954 , 0.17730496,
#         0.34920635, 0.50580986, 0.66433566, 0.10169492],
#        [1.        , 0.42105263, 0.        , 1.        , 0.        ,
#         0.        , 0.        , 0.        , 0.35201149, 0.20803783,
#         0.33862434, 0.44612676, 0.52447552, 0.08474576],
#        [0.        , 0.76315789, 0.66666667, 1.        , 0.        ,
#         0.        , 1.        , 0.        , 0.32327586, 0.3144208 ,
#         0.4973545 , 0.50316901, 0.45454545, 0.1779661 ],
#        [0.        , 0.36842105, 0.66666667, 1.        , 0.        ,
#         0.        , 0.        , 0.        , 0.40948276, 0.21985816,
#         0.38095238, 0.40669014, 0.59440559, 0.12711864]])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y ,
                                   random_state=1000, 
                                   test_size=0.10, 
                                   shuffle=True)

# %%
clf =  LogisticRegression(random_state = 0)

# %%
clf.fit(X_train,Y_train)
# Out:
# /home/crl/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
k = True
while(k):
    k = input("Do you want to cont...")
    test = input()

    #preprocessing
#     Y_pred = clf.predict(test)
    print(test)
# Out:
# Do you want to cont...1
# a,b,c,d,e,f,g
# a,b,c,d,e,f,g
# Do you want to cont...1
# f1,f2,f3
# f1,f2,f3

# %%
Y_pred = clf.predict(X_test)

# %%
score1 = accuracy_score(Y_test,Y_pred)

# %%
f1_score(Y_test, Y_pred, average='macro')
# Out:
# 0.4918164849199332

# %%
score1
# Out:
# 0.8561320754716981

# %%
from sklearn.metrics import precision_score

# %%
precision_score(y_test, y_pred, average='macro')
# Out:
# 0.7463942307692308

# %%
precision_score(Y_test, Y_pred, average='macro')
# Out:
# 0.6307875894988066

# %%
from sklearn.metrics import recall_score

# %%
recall_score(y_test, y_pred, average='macro')
# Out:
# 0.5375457875457875

# %%
recall_score(Y_test, Y_pred, average='macro')
# Out:
# 0.5125457875457876

# %%
df2 = df1.drop(columns = ['prevalentHyp'])

# %%
x1= df2.drop(columns = ['TenYearCHD'])

# %%
y1 = df2['TenYearCHD']

# %%
x1
# Out:
#       male  age  education  currentSmoker  BPMeds  prevalentStroke  diabetes  \
# 0        1   39        4.0              0     0.0                0         0
# 1        0   46        2.0              0     0.0                0         0
# 2        1   48        1.0              1     0.0                0         0
# 3        0   61        3.0              1     0.0                0         0
# 4        0   46        3.0              1     0.0                0         0
# ...    ...  ...        ...            ...     ...              ...       ...
# 4235     0   48        2.0              1     0.0                0         0
# 4236     0   44        1.0              1     0.0                0         0
# 4237     0   52        2.0              0     0.0                0         0
# 4238     1   40        3.0              0     0.0                0         0
# 4239     0   39        3.0              1     0.0                0         0
#
# ...

# %%
Scaler2= MinMaxScaler(feature_range=(0,1))

# %%
rescaledx1 = Scaler2.fit_transform(x1)

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1,y1 ,
                                   random_state=1000, 
                                   test_size=0.10, 
                                   shuffle=True)

# %%
clf1 = LogisticRegression(random_state = 0)

# %%
clf1.fit(x1_train,y1_train)
# Out:
# /home/crl/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
y1_pred = clf1.predict(x1_test)

# %%
f1_score(y1_test, y1_pred, average='macro')
# Out:
# 0.5070913740990467

# %%
from sklearn.preprocessing import StandardScaler

# %%
sca = StandardScaler()

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
ys = df['TenYearCHD']

# %%
xs = df.drop (columns = ['TenYearCHD'])

# %%
xs[["age", "cigsPerDay","totChol","sysBP","diaBP","BMI","heartRate","glucose","currentSmoker"]] = sca.fit_transform(df[["age", "cigsPerDay","totChol","sysBP","diaBP","BMI","heartRate","glucose","currentSmoker"]])

# %%
xs_train, xs_test,ys_train, ys_test = train_test_split(x,y,test_size = 0.33)

# %%
md1 = LogisticRegression(penalty = 'l2')
md1.fit(xs_train,ys_train)
# Out:
# /home/crl/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
ys_pred = md1.predict(xs_test)

# %%
print ('Score = ', md1.score(xs_test,ys_test))
# Out:
# Score =  0.8478571428571429

# %%
print(classification_report (ys_test,ys_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92      1184
#            1       0.58      0.05      0.09       216
#
#     accuracy                           0.85      1400
#    macro avg       0.72      0.52      0.51      1400
# weighted avg       0.81      0.85      0.79      1400
